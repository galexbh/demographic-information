# %% [markdown]
# <a href="https://colab.research.google.com/github/galexbh/demographic-information/blob/main/src/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/UNAH/IA/unemployment analysis.csv", delimiter=",")
df_fertility = pd.read_csv("/content/drive/MyDrive/UNAH/IA/homework/Fertility.csv").drop(columns=["Country"])
df_GDP = pd.read_csv("/content/drive/MyDrive/UNAH/IA/homework/GDP per capita.csv").drop(columns=["Country"])
df_suicide = pd.read_csv("/content/drive/MyDrive/UNAH/IA/homework/Suicide rate.csv").drop(columns=["Country"])
df_population = pd.read_csv("/content/drive/MyDrive/UNAH/IA/homework/Population growth.csv").drop(columns=["Country"])
df_country = df_fertility.merge(df_GDP, how="inner", on="ISO-code")
df_country = df_country.merge(df_suicide, how="inner", on="ISO-code")
df_country = df_country.merge(df_population, how="inner", on="ISO-code")

# %%
df_country
# Out:
#      Fertility ISO-code  GDP per capita  Suicide rate  Population growth
# 0          4.5      AFG          2182.0           6.4               2.41
# 1          1.6      ALB         14866.0           5.6               0.26
# 2          3.0      DZA         16091.0           3.3               1.89
# 3          5.5      AGO          6763.0           8.9               3.12
# 4          2.0      ATG         30593.0           0.5               1.03
# ..         ...      ...             ...           ...                ...
# 186        2.3      VEN         16055.0           3.8               1.53
# 187        2.0      VNM          8677.0           7.0               1.06
# 188        3.8      YEM          2312.0           9.8               2.33
# 189        4.6      ZMB          4174.0          11.3               3.19
# 190        3.6      ZWE          2778.0          19.1               2.70
#
# [191 rows x 5 columns]

# %%
df.describe()
# Out:
#              1991        1992        1993        1994        1995        1996  \
# count  235.000000  235.000000  235.000000  235.000000  235.000000  235.000000
# mean     7.278000    7.626340    8.070766    8.246043    8.333915    8.494894
# std      6.013749    6.296617    6.335855    6.243778    6.330822    6.358431
# min      0.300000    0.340000    0.410000    0.470000    0.500000    0.560000
# 25%      2.945000    3.140000    3.700000    3.890000    3.945000    3.995000
# 50%      5.410000    5.710000    6.030000    6.550000    6.700000    7.050000
# 75%      9.815000   10.170000   10.895000   11.110000   11.050000   11.405000
# max     36.120000   36.390000   36.740000   36.980000   37.340000   38.800000
#
#              1997        1998        1999        2000  ...        2012  \
# count  235.000000  235.000000  235.000000  235.000000  ...  235.000000
# mean     8.394043    8.441064    8.568043    8.438979  ...    8.062553
# ...

# %%
dffinal = pd.DataFrame()
for y in df.columns[ 2 :  ]:
    dftemp  = df.loc[ :  , ['Country Name','Country Code', y] ]
    dftemp['Year'] = y
    dftemp.columns = ['Country Name', 'Country Code', 'Value', 'Year']
    dftemp = dftemp.loc[ : , ['Country Name', 'Country Code', 'Year', 'Value'] ]
    
    dffinal = pd.concat([dffinal, dftemp])

# %%
dffinal
# Out:
#                     Country Name Country Code  Year  Value
# 0    Africa Eastern and Southern          AFE  1991   7.80
# 1                    Afghanistan          AFG  1991  10.65
# 2     Africa Western and Central          AFW  1991   4.42
# 3                         Angola          AGO  1991   4.21
# 4                        Albania          ALB  1991  10.31
# ..                           ...          ...   ...    ...
# 230                        Samoa          WSM  2021   9.84
# 231                  Yemen, Rep.          YEM  2021  13.57
# 232                 South Africa          ZAF  2021  33.56
# 233                       Zambia          ZMB  2021  13.03
# 234                     Zimbabwe          ZWE  2021   5.17
#
# [7285 rows x 4 columns]

# %%
#df_demographic = pd.merge(dffinal, df_country, left_on="Country Code", right_on="ISO-code", how="left")
#df_demographic.drop(['ISO-code'], axis=1)
df_demographic = dffinal.join(df_country, how="left").drop(['ISO-code'], axis=1)
df_demographic
# Out:
#                     Country Name Country Code  Year  Value  Fertility  \
# 0    Africa Eastern and Southern          AFE  1991   7.80        4.5
# 0    Africa Eastern and Southern          AFE  1992   7.84        4.5
# 0    Africa Eastern and Southern          AFE  1993   7.85        4.5
# 0    Africa Eastern and Southern          AFE  1994   7.84        4.5
# 0    Africa Eastern and Southern          AFE  1995   7.83        4.5
# ..                           ...          ...   ...    ...        ...
# 234                     Zimbabwe          ZWE  2017   4.78        NaN
# 234                     Zimbabwe          ZWE  2018   4.80        NaN
# 234                     Zimbabwe          ZWE  2019   4.83        NaN
# 234                     Zimbabwe          ZWE  2020   5.35        NaN
# 234                     Zimbabwe          ZWE  2021   5.17        NaN
#
#      GDP per capita  Suicide rate  Population growth
# 0            2182.0           6.4               2.41
# ...
